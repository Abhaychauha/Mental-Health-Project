# %% [markdown]
# # **Mental Health in Tech Survey — Exploratory Data Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Your Name

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project explores the **2014 Mental Health in Tech Survey**, a dataset of 1,259 responses collected from employees (largely in the technology industry) that captures demographics, workplace policies, and personal attitudes toward mental health at work. The goal of this EDA is to understand how mental health is perceived, supported, and disclosed in tech workplaces, and to surface the factors most associated with an employee seeking treatment for a mental health condition.
#
# The dataset contains 27 columns covering respondent demographics (Age, Gender, Country, State), employer characteristics (company size, whether the company is a tech company, remote-work policy), the mental-health support infrastructure employers provide (benefits, care options, wellness programs, seek-help resources, anonymity protections, ease of leave), and the respondent's personal attitudes and disclosure comfort (willingness to discuss mental health with coworkers/supervisors, fear of negative consequences, whether they have a family history of mental illness, and whether they have sought treatment).
#
# The data required substantial cleaning before analysis. The `Age` column contained clearly invalid entries (negative values and values in the billions), which were filtered to a realistic working-age range. The `Gender` column had 49 unique free-text responses due to it being an open text field, which were consolidated into three consistent categories: Male, Female, and Other. Columns such as `state` (only applicable to US respondents), `self_employed`, and `work_interfere` contained missing values that were handled contextually — `self_employed` nulls were treated as "No", and `work_interfere` nulls (respondents without a mental health condition) were labeled as "Not applicable". The largely-empty free-text `comments` column was dropped from the numerical analysis.
#
# After cleaning, the EDA moves through univariate analysis (who responded — age, gender, country, company size), then bivariate/multivariate analysis connecting workplace support factors (benefits, care options, anonymity, leave ease) and personal factors (family history, remote work) to the key outcome variable: whether the respondent sought treatment. Fifteen visualizations — including bar charts, stacked/grouped comparisons, box plots, a correlation heatmap, and a pair plot — are used to tell this story, each paired with a rationale for the chart choice and the business insight it produces.
#
# Key patterns that emerge include a strong association between family history of mental illness and treatment-seeking, a clear link between employer-provided benefits/care-option clarity and treatment rates, and workplace-size and geography effects on both support availability and reported attitudes. These findings are translated into concrete recommendations for tech employers on how to design mental-health support programs that measurably increase help-seeking behavior, reduce stigma, and protect employee wellbeing — directly relevant to HR and People Ops teams building or auditing mental-health benefits programs.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/your-username/mental-health-tech-survey-eda

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Mental health remains one of the most under-addressed areas of employee wellbeing, particularly in the high-pressure tech industry. Despite growing awareness, many employees remain unsure of what support their employer offers, and many still fear that disclosing a mental health condition will negatively affect their career. This project analyzes the 2014 OSMI Mental Health in Tech Survey to understand **who is affected, what workplace factors correlate with seeking treatment, and where the biggest gaps in support and awareness exist**, so that companies can design more effective, stigma-reducing mental health programs.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to help **HR leaders, People Operations teams, and tech company management** understand:
# 1. Which employee segments (by demographics, company size, geography) are most and least likely to seek mental health treatment.
# 2. Which workplace policies (benefits, care-option transparency, anonymity, ease of leave, wellness programs) are most strongly associated with higher treatment-seeking and more open attitudes.
# 3. Where stigma and fear of negative consequences are still barriers, so that targeted interventions (awareness campaigns, manager training, clearer benefits communication) can be designed to close these gaps and build a psychologically safer workplace.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('survey.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Number of Rows    : {df.shape[0]}")
print(f"Number of Columns : {df.shape[1]}")
# Out:
# Number of Rows    : 1259
# Number of Columns : 27

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   str
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   str
#  3   Country                    1259 non-null   str
#  4   state                      744 non-null    str
#  5   self_employed              1241 non-null   str
#  6   family_history             1259 non-null   str
#  7   treatment                  1259 non-null   str
#  8   work_interfere             995 non-null    str
#  9   no_employees               1259 non-null   str
#  10  remote_work                1259 non-null   str
#  11  tech_company               1259 non-null   str
#  12  benefits                   1259 non-null   str
#  13  care_options               1259 non-null   str
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing = df.isnull().sum().sort_values(ascending=False)
missing_pct = (missing / len(df) * 100).round(2)
missing_df = pd.DataFrame({'Missing Count': missing, 'Missing %': missing_pct})
missing_df[missing_df['Missing Count'] > 0]
# Out:
#                 Missing Count  Missing %
# comments                 1095      86.97
# state                     515      40.91
# work_interfere            264      20.97
# self_employed              18       1.43

# %%
# Visualizing the missing values
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Values Heatmap', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# - The dataset has **1,259 rows and 27 columns**, with **no duplicate rows**.
# - Most columns are categorical (object/string type), except `Age` which is numeric and `Timestamp` which is a date string.
# - Four columns have missing values: `comments` (~87% missing — mostly unused free text), `state` (~41% missing — only applicable to US respondents), `work_interfere` (~21% missing — only applicable to respondents with a mental health condition), and `self_employed` (~1.4% missing).
# - The `Age` column contains clearly invalid entries (negative numbers and absurdly large numbers), which must be cleaned before analysis.
# - The `Gender` column is a free-text field with many inconsistent spellings/variants of Male/Female/Other that need to be standardized.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns.tolist()
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence',
#  'comments']

# %%
# Dataset Describe
df.describe(include='all').T
# Out:
#                             count unique                              top  \
# Timestamp                    1259   1246              2014-08-27 12:31:41
# Age                        1259.0    NaN                              NaN
# Gender                       1259     49                             Male
# Country                      1259     48                    United States
# state                         744     45                               CA
# self_employed                1241      2                               No
# family_history               1259      2                               No
# treatment                    1259      2                              Yes
# work_interfere                995      4                        Sometimes
# no_employees                 1259      6                             6-25
# remote_work                  1259      2                               No
# tech_company                 1259      2                              Yes
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - **Timestamp**: Date/time the survey was filled.
# - **Age**: Respondent's age (contains data-entry errors requiring cleaning).
# - **Gender**: Self-reported gender identity (free text, requires standardization).
# - **Country / State**: Respondent's location; State is only populated for US respondents.
# - **self_employed, family_history, treatment, remote_work, tech_company, obs_consequence**: Yes/No fields.
# - **work_interfere**: How much a mental health condition interferes with work (Never/Rarely/Sometimes/Often), blank if the respondent has no condition.
# - **no_employees**: Company size bucket.
# - **benefits, care_options, wellness_program, seek_help, anonymity**: Employer-provided mental health support, mostly Yes/No/Don't know.
# - **leave**: Ease of taking mental-health leave (5-point ordinal scale).
# - **mental_health_consequence, phys_health_consequence, coworkers, supervisor, mental_health_interview, phys_health_interview**: Attitude/comfort-level questions, mostly Yes/No/Maybe or comfort-level scales.
# - **mental_vs_physical**: Whether the employer treats mental health as seriously as physical health.
# - **comments**: Optional free-text comments (mostly empty).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    print(f"{col:28s} -> {df[col].nunique()} unique values")
# Out:
# Timestamp                    -> 1246 unique values
# Age                          -> 53 unique values
# Gender                       -> 49 unique values
# Country                      -> 48 unique values
# state                        -> 45 unique values
# self_employed                -> 2 unique values
# family_history               -> 2 unique values
# treatment                    -> 2 unique values
# work_interfere               -> 4 unique values
# no_employees                 -> 6 unique values
# remote_work                  -> 2 unique values
# tech_company                 -> 2 unique values
# benefits                     -> 3 unique values
# care_options                 -> 3 unique values
# wellness_program             -> 3 unique values
# seek_help                    -> 3 unique values
# anonymity                    -> 3 unique values
# leave                        -> 5 unique values
# mental_health_consequence    -> 3 unique values
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df_clean = df.copy()

# 1. Parse Timestamp
df_clean["Timestamp"] = pd.to_datetime(df_clean["Timestamp"])

# 2. Clean Age: keep a realistic working-age range (18-75), fix impossible values
df_clean.loc[(df_clean["Age"] < 18) | (df_clean["Age"] > 75), "Age"] = np.nan
df_clean["Age"] = df_clean["Age"].fillna(df_clean["Age"].median())
df_clean["Age"] = df_clean["Age"].astype(int)

# 3. Create Age Groups for easier grouping
bins = [17, 24, 29, 34, 39, 44, 49, 75]
labels = ["18-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50+"]
df_clean["Age_Group"] = pd.cut(df_clean["Age"], bins=bins, labels=labels)

# 4. Clean Gender into 3 consistent categories: Male, Female, Other
def clean_gender(g):
    g = str(g).strip().lower()
    male_terms = ["male", "m", "man", "cis male", "cis man", "mail", "malr", "maile",
                  "make", "mal", "msle", "guy (-ish) ^_^", "male-ish", "male (cis)",
                  "male leaning androgynous", "ostensibly male, unsure what that really means",
                  "something kinda male?"]
    female_terms = ["female", "f", "woman", "cis female", "cis-female/femme", "femake",
                     "female (cis)", "female (trans)", "femail", "trans-female", "trans woman"]
    if g in male_terms:
        return "Male"
    elif g in female_terms:
        return "Female"
    else:
        return "Other"

df_clean["Gender_Clean"] = df_clean["Gender"].apply(clean_gender)

# 5. Handle missing values contextually
df_clean["self_employed"] = df_clean["self_employed"].fillna("No")
df_clean["work_interfere"] = df_clean["work_interfere"].fillna("Not applicable")
df_clean["state"] = df_clean["state"].fillna("Not in US")

# 6. Drop the mostly-empty free text comments column (not useful for quantitative EDA)
df_clean.drop(columns=["comments"], inplace=True)

print("Shape after cleaning:", df_clean.shape)
df_clean.head()
# Out:
# Shape after cleaning: (1259, 28)
#             Timestamp  Age  Gender         Country      state self_employed  \
# 0 2014-08-27 11:29:31   37  Female   United States         IL            No
# 1 2014-08-27 11:29:37   44       M   United States         IN            No
# 2 2014-08-27 11:29:44   32    Male          Canada  Not in US            No
# 3 2014-08-27 11:29:46   31    Male  United Kingdom  Not in US            No
# 4 2014-08-27 11:30:22   31    Male   United States         TX            No
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# - **Age** was cleaned by removing invalid entries (negative numbers, absurd values in the billions) and clipping to a realistic 18–75 working-age range; remaining nulls were filled with the median age. An `Age_Group` bucket column was also created for easier comparison across charts.
# - **Gender** was consolidated from 49 messy free-text variants down to **Male / Female / Other** using a mapping function, making group comparisons meaningful.
# - Missing values were filled **contextually** rather than dropped: `self_employed` nulls → "No" (majority class), `work_interfere` nulls → "Not applicable" (these are respondents without a mental health condition, so the question doesn't apply to them), and `state` nulls → "Not in US" (since state only applies to US respondents).
# - The `comments` column was dropped since it was ~87% empty free text and not suited for quantitative analysis.
# - These steps ensure every remaining column is complete and consistently coded, which is required before building reliable, comparable visualizations.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(df_clean['Age'], bins=25, kde=True, color='#4C72B0')
plt.axvline(df_clean['Age'].median(), color='red', linestyle='--', label=f"Median = {df_clean['Age'].median():.0f}")
plt.title('Distribution of Respondent Age', fontsize=14, fontweight='bold')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a KDE overlay is the standard choice for visualizing the distribution (shape, spread, central tendency) of a single continuous variable like Age.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The respondent base is heavily concentrated between **25 and 40 years old**, with a median age around **31**, indicating the survey mostly captures early-to-mid career tech professionals rather than very junior or senior employees.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this tells companies that mental-health programs should be designed primarily around the needs of **25-40 year old professionals** (e.g., career-stage stressors, family-planning stress, burnout in mid-career roles), while still ensuring younger and older employees aren't overlooked in outreach.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 6))
order = df_clean['Gender_Clean'].value_counts().index
ax = sns.countplot(data=df_clean, x='Gender_Clean', order=order, palette='viridis')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x()+p.get_width()/2, p.get_height()),
                ha='center', va='bottom', fontsize=11)
plt.title('Respondent Count by Gender', fontsize=14, fontweight='bold')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count bar chart is the clearest way to compare frequencies across a small number of categories like the three cleaned gender groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The sample is heavily **male-skewed** (roughly 79% of respondents), consistent with the tech industry's known gender imbalance, with Female (~18%) and Other/non-binary (~3%) respondents a clear minority.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — any conclusions about gender differences in mental health attitudes must be read with caution given this imbalance, and companies should ensure outreach and support programs are inclusive and don't implicitly center only the majority group's experience.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
top_countries = df_clean['Country'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='crest')
plt.title('Top 10 Countries by Number of Respondents', fontsize=14, fontweight='bold')
plt.xlabel('Number of Respondents')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart works best for ranking categories (countries) with long labels by a single numeric value (respondent count).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **United States dominates** the dataset (~60% of respondents), followed distantly by the **United Kingdom** (~15%) and **Canada** (~6%) — the survey is effectively US-centric with a long tail of other countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes and no — insights on country-level policy or cultural effects (e.g., leave laws) will be statistically reliable mainly for the US and UK; conclusions for countries with very few respondents should not be generalized, which is an important caveat for any global people-strategy team using this data.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(6, 6))
treatment_counts = df_clean['treatment'].value_counts()
colors = ['#55A868', '#C44E52']
plt.pie(treatment_counts.values, labels=treatment_counts.index, autopct='%1.1f%%',
        startangle=90, colors=colors, explode=(0.02, 0.02))
plt.title('Have You Sought Treatment for a Mental Health Condition?', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is appropriate here since `treatment` is a simple binary variable and the goal is to show the overall proportion split, which is the key outcome metric for the rest of the analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The sample is almost **evenly split** — about 50.6% have sought treatment vs 49.4% who have not — showing that mental health conditions and treatment-seeking are extremely common among tech employees, not a fringe issue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this is a strong signal that mental health support cannot be treated as a low-priority or niche benefit; roughly half the workforce in this sample has personally sought treatment, justifying real investment in support programs.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df_clean, x='family_history', hue='treatment', palette='Set2')
plt.title('Family History of Mental Illness vs Treatment Sought', fontsize=14, fontweight='bold')
plt.xlabel('Family History of Mental Illness')
plt.ylabel('Count')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped (hue) count bar chart is ideal for comparing how one categorical variable's distribution changes across levels of another categorical variable — here, treatment-seeking split by family history.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Respondents with a **family history of mental illness are far more likely to seek treatment (~74%)** compared to those without one (~35%), making family history the strongest single predictor of treatment-seeking behavior identified in this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — genetic/familial risk awareness could be built into proactive wellness outreach; employees who disclose family history (privately, e.g. to EAP providers) could be offered earlier, easier access to mental health resources.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(9, 6))
order = ['Never', 'Rarely', 'Sometimes', 'Often', 'Not applicable']
order = [o for o in order if o in df_clean['work_interfere'].unique()]
ax = sns.countplot(data=df_clean, x='work_interfere', order=order, palette='rocket')
plt.title('Does Mental Health Interfere With Work?', fontsize=14, fontweight='bold')
plt.xlabel('Frequency of Work Interference')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# An ordered bar chart preserves the natural ordinal sequence (Never → Rarely → Sometimes → Often) of this survey question, making the trend easy to read.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Among respondents for whom the question applies, **'Sometimes'** is by far the most common answer, and a sizeable group reports their condition interferes with work **'Often'** — confirming that mental health has a tangible, ongoing productivity impact for a large share of employees, not just an occasional one.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this justifies flexible-work and accommodation policies (e.g. adjustable workloads, quiet spaces, flexible deadlines) as a practical productivity investment, not just a wellbeing nice-to-have.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
size_order = ['1-5', '6-25', '26-100', '100-500', '500-1000', 'More than 1000']
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df_clean, x='no_employees', order=size_order, palette='mako')
plt.title('Respondents by Company Size', fontsize=14, fontweight='bold')
plt.xlabel('Number of Employees')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# An ordered bar chart clearly shows how respondents are spread across a naturally ordered categorical scale (company-size buckets).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Respondents are fairly evenly spread across company sizes, with **6-25**, **26-100**, and **'More than 1000'** employees being the most represented brackets — meaning the dataset captures both startup and large-enterprise experiences well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — since support programs (formal benefits, HR-run wellness programs) are more feasible at large companies, this diversity lets the analysis meaningfully compare how organization size relates to mental-health support and outcomes later in the notebook.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df_clean, x='remote_work', hue='treatment', palette='pastel')
plt.title('Remote Work vs Treatment Sought', fontsize=14, fontweight='bold')
plt.xlabel('Works Remotely ≥ 50% of the Time')
plt.ylabel('Count')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped count bar chart directly compares treatment-seeking rates between remote and non-remote employees, which is the relationship of interest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Treatment-seeking rates are **nearly identical** between remote (~53%) and non-remote (~50%) workers, suggesting remote work status alone is not a major differentiator in whether someone seeks mental health treatment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Neutral — this is a useful null-result: it means companies shouldn't assume remote employees are inherently more or less likely to need mental health support, so support programs should be designed to reach both groups equally rather than assuming remote workers are more isolated (or more protected).

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(9, 6))
ax = sns.countplot(data=df_clean, x='benefits', hue='treatment',
                    order=['Yes', "Don't know", 'No'], palette='Set1')
plt.title('Employer Mental Health Benefits vs Treatment Sought', fontsize=14, fontweight='bold')
plt.xlabel('Employer Provides Mental Health Benefits')
plt.ylabel('Count')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart lets us directly compare treatment-seeking rates across the three benefit-availability categories (Yes / Don't know / No), revealing whether employer support correlates with actual help-seeking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Employees who know their employer **provides benefits seek treatment at the highest rate (~64%)**, compared to only ~48% when benefits are absent and just ~37% when the employee **doesn't even know** if benefits exist — the 'Don't know' group has the lowest treatment rate of all.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, strongly — this is one of the most actionable findings: simply **communicating existing benefits more clearly** could lift treatment-seeking rates, since not knowing about support is worse than having none confirmed at all.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(9, 6))
ax = sns.countplot(data=df_clean, x='care_options', hue='treatment',
                    order=['Yes', 'Not sure', 'No'], palette='Set1')
plt.title('Awareness of Care Options vs Treatment Sought', fontsize=14, fontweight='bold')
plt.xlabel('Employee Knows Employer Mental Health Care Options')
plt.ylabel('Count')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Same grouped-bar approach as the benefits chart, since `care_options` is another employer-support categorical variable being compared against the treatment outcome.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This shows the **strongest support-related effect in the dataset**: employees who know their care options seek treatment ~69% of the time, versus ~41% for 'No' and ~39% for 'Not sure' — awareness of *how* to get help matters even more than whether benefits exist at all.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this is the single clearest ROI opportunity for HR: investing in **clear, repeated communication of exactly what mental health care options are available** (not just that benefits exist) is likely to meaningfully increase treatment-seeking.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
leave_order = ['Very easy', 'Somewhat easy', "Don't know", 'Somewhat difficult', 'Very difficult']
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df_clean, x='leave', order=leave_order, palette='flare')
plt.title('Ease of Taking Medical Leave for a Mental Health Condition', fontsize=13, fontweight='bold')
plt.xlabel('Perceived Ease of Leave')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# An ordered bar chart preserves the natural ease-to-difficulty scale of this survey question, making it easy to see where the distribution skews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A large share of respondents simply **don't know** how easy it would be to take mental health leave, and 'Somewhat difficult'/'Very difficult' responses together outweigh the 'easy' responses — signaling both a real difficulty and a communication/awareness gap around leave policy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — uncertainty and perceived difficulty around leave can itself discourage employees from ever starting the process; clearly documented, easily-accessible leave policies for mental health could remove this friction.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
comfort = pd.DataFrame({
    'Coworkers': df_clean['coworkers'].value_counts(normalize=True) * 100,
    'Supervisor': df_clean['supervisor'].value_counts(normalize=True) * 100
}).fillna(0)
comfort = comfort.reindex(['Yes', 'Some of them', 'No']).fillna(comfort.reindex(['Yes','No']).iloc[0]*0)
comfort = comfort.loc[['Yes', 'Some of them', 'No']]
comfort.plot(kind='bar', figsize=(9, 6), color=['#4C72B0', '#DD8452'])
plt.title('Willingness to Discuss Mental Health: Coworkers vs Supervisor', fontsize=13, fontweight='bold')
plt.xlabel('Willingness to Discuss')
plt.ylabel('Percentage of Respondents (%)')
plt.xticks(rotation=0)
plt.legend(title='')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart comparing two related percentage distributions side by side is the clearest way to contrast comfort levels across two different audiences (coworkers vs. supervisor).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Employees are somewhat more willing to discuss mental health with **coworkers** than with their **direct supervisor**, and a notable share answer 'No' to both — showing that hierarchical power dynamics add an extra layer of hesitation around disclosure to management specifically.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this points to a need for **manager-specific training** on how to receive mental health disclosures supportively, since the supervisor relationship is where the most disclosure hesitancy exists and where trust-building would have outsized impact.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_clean, x='treatment', y='Age', palette='coolwarm')
plt.title('Age Distribution by Treatment-Seeking Status', fontsize=14, fontweight='bold')
plt.xlabel('Sought Treatment')
plt.ylabel('Age')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is the standard way to compare the distribution (median, spread, outliers) of a continuous variable (Age) across two groups (treatment Yes/No).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The age distributions for both groups are **very similar** (median around 31 in both), with only a slightly higher median age among those who sought treatment — age alone is not a strong differentiator of treatment-seeking behavior in this sample.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Neutral — this tells companies that mental-health outreach shouldn't be narrowly age-targeted; the need for support is broadly distributed across the working-age population rather than concentrated in a specific age band.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
encode_cols = ['family_history', 'treatment', 'remote_work', 'tech_company',
               'benefits', 'care_options', 'wellness_program', 'seek_help',
               'anonymity', 'mental_health_consequence', 'phys_health_consequence',
               'obs_consequence']

df_encoded = df_clean[encode_cols + ['Age']].copy()
for col in encode_cols:
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

plt.figure(figsize=(12, 9))
corr = df_encoded.corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0,
            linewidths=0.5, square=True)
plt.title('Correlation Heatmap of Key Encoded Variables', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is the best way to simultaneously view pairwise relationships across many label-encoded categorical/numeric variables at once, quickly spotting the strongest positive/negative associations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **`family_history` and `treatment` show the strongest positive correlation** in the matrix, confirming the earlier chart. `care_options`, `benefits`, and `anonymity` also correlate positively with `treatment`, while `mental_health_consequence` and `phys_health_consequence` correlate with each other (employees who fear consequences for one tend to fear it for the other) — reinforcing that support-infrastructure variables cluster together and personal/family risk factors cluster separately.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
pairplot_cols = ['Age', 'family_history', 'treatment', 'benefits', 'care_options']
df_pair = df_clean[pairplot_cols].copy()
for col in ['family_history', 'treatment', 'benefits', 'care_options']:
    df_pair[col] = df_pair[col].astype('category').cat.codes

sns.pairplot(df_pair, hue='treatment', palette='husl', diag_kind='kde', corner=True)
plt.suptitle('Pair Plot of Age & Key Encoded Support/Risk Variables', y=1.02, fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot gives a compact overview of pairwise relationships and distributions across several key variables at once, colored by the outcome variable (treatment), useful as a final multivariate sanity-check after the individual bivariate charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot confirms there is no simple linear separation of the two treatment groups by Age alone, but visible density shifts between the treatment classes along `family_history`, `benefits`, and `care_options` reinforce that these categorical/support factors — not age — are the more meaningful drivers of the treatment-seeking outcome.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the EDA, tech employers should focus on three concrete levers to improve mental health outcomes and treatment-seeking among employees:
#
# 1. **Close the awareness gap, not just the benefits gap.** The data shows that not knowing about benefits or care options is associated with *lower* treatment-seeking than even having no benefits at all. Companies should run recurring, clear communication (onboarding, intranet, manager reminders) about exactly what mental health support is available and how to access it — this is likely the highest-ROI intervention identified.
# 2. **Invest in manager-level trust and training.** Employees are more comfortable discussing mental health with coworkers than with direct supervisors. Training managers to respond supportively and confidentially to disclosures can reduce this gap and encourage earlier help-seeking, especially since supervisors often control access to accommodations and leave.
# 3. **Simplify and clearly document mental health leave.** A large share of respondents don't know how easy it would be to take leave for a mental health condition. Publishing an unambiguous, easy-to-find leave policy (ideally matching the ease of physical-health leave) removes a major source of hesitation.
#
# Because treatment-seeking is roughly evenly split across age, remote-work status, and gender in this sample, these interventions should be applied **broadly across the whole workforce** rather than narrowly targeted, while paying special attention to employees with a family history of mental illness, who are both the most likely to need support and the most predictive group to reach proactively.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This EDA of the 2014 Mental Health in Tech Survey shows that mental health challenges are common and evenly distributed across the tech workforce — roughly half of respondents have sought treatment, largely independent of age, remote-work status, or company size. The strongest predictors of treatment-seeking were **not demographic** but **support-related and personal-risk-related**: having a family history of mental illness, and — critically — **knowing** what mental health benefits and care options an employer provides. Employees who were simply unaware of their support options sought treatment at the lowest rates in the dataset, even lower than those with no benefits at all, highlighting that clear communication of existing support may matter as much as the support itself. Combined with the finding that employees are less comfortable disclosing mental health issues to supervisors than to coworkers, and that many don't know how easy it is to take mental health leave, this analysis points to a clear, low-cost, high-impact action plan for tech employers: communicate benefits clearly and repeatedly, train managers to handle disclosures well, and simplify and publicize leave policies. These changes target the specific gaps — awareness and trust — that this data shows are holding back mental health support from reaching the employees who need it.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
